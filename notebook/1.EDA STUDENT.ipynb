# %%
# Import necessary libraries
import pandas as pd # type: ignore

# Define the file path
file_path = "E:\\Github Repository\\notebook\\StudentsPerformance.csv"

# Load the CSV file into a DataFrame
try:
    data = pd.read_csv(file_path)
    print("File loaded successfully!")
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
    exit()

# Display the first few rows of the dataset
print("First 5 rows of the dataset:")
print(data.head())
# Out:
# File loaded successfully!
# First 5 rows of the dataset:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
print(data.head()) # type: ignore
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.select_dtypes(include=['object']).columns
data["gender"].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
numerical_columns=data.select_dtypes(include=["number"]).columns
categorical_columns=numerical_columns=data.select_dtypes(include=["object"]).columns

# %%
data["total_score"]=data["math score"]+data["reading score"]+data["writing score"]

# %%
data["average"]=data["total_score"]/3
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
reading_score_full = data[data["reading score"] == 100]["average"].count()
reading_score_full
writing_score_full = data[data["writing score"] == 100]["average"].count()
writing_score_full
math_score_full = data[data["math score"] == 100]["average"].count()
math_score_full
print("Total number of students who scored full marks in reading, writing, and math:")
print(f"Reading: {reading_score_full}") 
print(f"Writing: {writing_score_full}")
# Out:
# Total number of students who scored full marks in reading, writing, and math:
# Reading: 17
# Writing: 14

# %%
reading_score_full = data[data["reading score"] <=20]["average"].count()
reading_score_full
writing_score_full = data[data["writing score"] <=20]["average"].count()
writing_score_full
math_score_full = data[data["math score"] <=20]["average"].count()
math_score_full
print("Total number of students who scored full marks in reading, writing, and math:")
print(f"Reading: {reading_score_full}") 
print(f"Writing: {writing_score_full}")
# Out:
# Total number of students who scored full marks in reading, writing, and math:
# Reading: 1
# Writing: 3

# %%
sns.histplot(data=data, x="average", kde=True, bins=30, hue="gender")
plt.title("Distribution of Average Scores")
plt.xlabel("Average Score")
plt.ylabel("Frequency")
plt.show()

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Filter data for females
female_data = data[data["gender"] == "female"]

# Ensure the filtered data is not empty
if not female_data.empty:
	sns.histplot(data=female_data, x="average", kde=True, bins=30, hue="lunch")
	plt.title("Distribution of Average Scores for Females")
	plt.xlabel("Average Score")
	plt.ylabel("Frequency")
	plt.show()
else:
	print("No data available for females.")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter data for females
male_data = data[data["gender"] == "male"]

# Ensure the filtered data is not empty
if not female_data.empty:
	sns.histplot(data=male_data, x="average", kde=True, bins=30, hue="lunch")
	plt.title("Distribution of Average Scores for males")
	plt.xlabel("Average Score")
	plt.ylabel("Frequency")
	plt.show()
else:
	print("No data available for males.")

# %%
sns.boxplot(data=data,orient="h")
# Out:
# <Axes: >

# %%
sns.barplot(x="test preparation course", y="average", data=data)
plt.title("Test Preparation Course vs Average Score")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="parental level of education", y="average", data=data)
plt.title("Parental Level of Education vs Average Score")
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x="test preparation course", y="average", data=data)
plt.title("Boxplot of Test Preparation Course vs Average Score")
plt.show()

# %%
sns.countplot(x="test preparation course", data=data)
plt.title("Count of Students by Test Preparation Course")
plt.show()

# %%
plt.figure(figsize=(8,6))
# Select only numeric columns for correlation
numeric_data = data.select_dtypes(include=["number"])
sns.heatmap(numeric_data.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(data, hue="gender")  # optional: hue by gender
plt.suptitle("Pairplot of Scores by Gender", y=1.02)
plt.show()
